# %%
import numpy as np
import tensorflow as tf
from sklearn.utils import shuffle
import re
import time
import collections
import os
import itertools
from tqdm import tqdm

# %%
def build_dataset(words, n_words, atleast=1):
    count = [['GO', 0], ['PAD', 1], ['EOS', 2], ['UNK', 3]]
    counter = collections.Counter(words).most_common(n_words)
    counter = [i for i in counter if i[1] >= atleast]
    count.extend(counter)
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

def add_start_end(string):
    string = string.split()
    strings = []
    for s in string:
        if s[-1] == '-':
            s = s[:-1]
        s = list(s)
        s[0] = '<%s'%(s[0])
        s[-1] = '%s>'%(s[-1])
        strings.extend(s)
    return strings

# %%
with open('stemmer-data-v5.txt','r') as fopen:
    texts = fopen.readlines()

# %%
after, before = [], []
for i in texts:
    splitted = i.encode('ascii', 'ignore').decode("utf-8").lower().split('\t')
    if len(splitted) < 2:
        continue
    after.append(add_start_end(splitted[1]))
    before.append(add_start_end(splitted[0]))
    
len(after), len(before)
# Out:
# (41528, 41528)

# %%
before[:5]
# Out:
# [['<s', 'p', 'i', 'd', 'e', 'r>'],
#  ['<t', 'r', 'a', 'n', 's', 'e', 'k', 's', 'u', 'a', 'l>'],
#  ['<k', 'h', 'u', 's', 'u', 's>'],
#  ['<k', 'r', 'i', 'm', 'i', 'n', 'o', 'l', 'o', 'g', 'i>'],
#  ['<n', 'e', 'g', 'e', 'r', 'i', 'p', 'i', 'n', 'g', 'a', 't>']]

# %%
after[:5]
# Out:
# [['<s', 'p', 'i', 'd', 'e', 'r>'],
#  ['<t', 'r', 'a', 'n', 's', 'e', 'k', 's', 'u', 'a', 'l>'],
#  ['<k', 'h', 'u', 's', 'u', 's>'],
#  ['<k', 'r', 'i', 'm', 'i', 'n', 'o', 'l', 'o', 'g', 'i>'],
#  ['<n', 'e', 'g', 'e', 'r', 'i', 'p', 'i', 'n', 'g', 'a', 't>']]

# %%
concat_from = list(itertools.chain(*before))
vocabulary_size_from = len(list(set(concat_from)))
data_from, count_from, dictionary_from, rev_dictionary_from = build_dataset(concat_from, vocabulary_size_from)
print('vocab from size: %d'%(vocabulary_size_from))
print('Most common words', count_from[4:10])
print('Sample data', data_from[:10], [rev_dictionary_from[i] for i in data_from[:10]])
print('filtered vocab size:',len(dictionary_from))
print("% of vocab used: {}%".format(round(len(dictionary_from)/vocabulary_size_from,4)*100))
# Out:
# vocab from size: 80
# Most common words [('a', 44151), ('e', 26905), ('n', 22703), ('i', 21583), ('r', 16110), ('u', 12472)]
# Sample data [27, 20, 7, 19, 5, 38, 35, 8, 4, 6] ['<s', 'p', 'i', 'd', 'e', 'r>', '<t', 'r', 'a', 'n']
# filtered vocab size: 84
# % of vocab used: 105.0%

# %%
concat_to = list(itertools.chain(*after))
vocabulary_size_to = len(list(set(concat_to)))
data_to, count_to, dictionary_to, rev_dictionary_to = build_dataset(concat_to, vocabulary_size_to)
print('vocab from size: %d'%(vocabulary_size_to))
print('Most common words', count_to[4:10])
print('Sample data', data_to[:10], [rev_dictionary_to[i] for i in data_to[:10]])
print('filtered vocab size:',len(dictionary_to))
print("% of vocab used: {}%".format(round(len(dictionary_to)/vocabulary_size_to,4)*100))
# Out:
# vocab from size: 80
# Most common words [('a', 35149), ('e', 18010), ('i', 17934), ('n', 15750), ('r', 12021), ('u', 11371)]
# Sample data [20, 21, 6, 17, 5, 32, 30, 8, 4, 7] ['<s', 'p', 'i', 'd', 'e', 'r>', '<t', 'r', 'a', 'n']
# filtered vocab size: 84
# % of vocab used: 105.0%

# %%
GO = dictionary_from['GO']
PAD = dictionary_from['PAD']
EOS = dictionary_from['EOS']
UNK = dictionary_from['UNK']

# %%
for i in range(len(after)):
    after[i].append('EOS')

# %%
class Stemmer:
    def __init__(self, size_layer, num_layers, embedded_size, 
                 from_dict_size, to_dict_size, learning_rate, 
                 dropout = 0.8, beam_width = 15, force_teaching_ratio=0.5):
        
        def lstm_cell(reuse=False):
            return tf.nn.rnn_cell.LSTMCell(size_layer, reuse=reuse)
        
        self.X = tf.placeholder(tf.int32, [None, None])
        self.X_seq_len = tf.count_nonzero(self.X, 1, dtype=tf.int32)
        self.Y = tf.placeholder(tf.int32, [None, None])
        self.Y_seq_len = tf.count_nonzero(self.Y, 1, dtype=tf.int32)
        batch_size = tf.shape(self.X)[0]

        encoder_embeddings = tf.Variable(tf.random_uniform([from_dict_size, embedded_size], -1, 1))
        encoder_embedded = tf.nn.embedding_lookup(encoder_embeddings, self.X)
        encoder_cells = tf.nn.rnn_cell.MultiRNNCell([lstm_cell() for _ in range(num_layers)])
        self.encoder_out, self.encoder_state = tf.nn.dynamic_rnn(cell = encoder_cells, 
                                                                 inputs = encoder_embedded, 
                                                                 sequence_length = self.X_seq_len,
                                                                 dtype = tf.float32)
        
        encoder_state = tuple(self.encoder_state[-1] for _ in range(num_layers))
        main = tf.strided_slice(self.Y, [0, 0], [batch_size, -1], [1, 1])
        decoder_input = tf.concat([tf.fill([batch_size, 1], GO), main], 1)
        decoder_embeddings = tf.Variable(tf.random_uniform([to_dict_size, embedded_size], -1, 1))
        dense_layer = tf.layers.Dense(to_dict_size)

        with tf.variable_scope('decode'):
            attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
            num_units = size_layer, 
            memory = encoder_embedded,
            memory_sequence_length = self.X_seq_len)
            decoder_cell = tf.contrib.seq2seq.AttentionWrapper(
                cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell() for _ in range(num_layers)]),
                attention_mechanism = attention_mechanism,
                attention_layer_size = size_layer)
            main = tf.strided_slice(self.Y, [0, 0], [batch_size, -1], [1, 1])
            decoder_input = tf.concat([tf.fill([batch_size, 1], GO), main], 1)
            training_helper = tf.contrib.seq2seq.ScheduledEmbeddingTrainingHelper(
            inputs = tf.nn.embedding_lookup(decoder_embeddings, decoder_input),
                sequence_length = self.Y_seq_len,
                embedding = decoder_embeddings,
                sampling_probability = 1 - force_teaching_ratio,
                time_major = False)
            training_decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = decoder_cell,
                helper = training_helper,
                initial_state = decoder_cell.zero_state(batch_size, tf.float32).clone(cell_state=encoder_state),
                output_layer = dense_layer)
            training_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = training_decoder,
                impute_finished = True,
                maximum_iterations = tf.reduce_max(self.Y_seq_len))

        with tf.variable_scope('decode', reuse=True):
            encoder_out_tiled = tf.contrib.seq2seq.tile_batch(encoder_embedded, beam_width)
            encoder_state_tiled = tf.contrib.seq2seq.tile_batch(encoder_state, beam_width)
            X_seq_len_tiled = tf.contrib.seq2seq.tile_batch(self.X_seq_len, beam_width)
            attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                num_units = size_layer, 
                memory = encoder_out_tiled,
                memory_sequence_length = X_seq_len_tiled)
            decoder_cell = tf.contrib.seq2seq.AttentionWrapper(
                cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell(reuse=True) for _ in range(num_layers)]),
                attention_mechanism = attention_mechanism,
                attention_layer_size = size_layer)
            predicting_decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = decoder_cell,
                embedding = decoder_embeddings,
                start_tokens = tf.tile(tf.constant([GO], dtype=tf.int32), [batch_size]),
                end_token = EOS,
                initial_state = decoder_cell.zero_state(batch_size * beam_width, tf.float32).clone(cell_state = encoder_state_tiled),
                beam_width = beam_width,
                output_layer = dense_layer,
                length_penalty_weight = 0.0)
            predicting_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = predicting_decoder,
                impute_finished = False,
                maximum_iterations = 2 * tf.reduce_max(self.X_seq_len))
            
            
        self.training_logits = training_decoder_output.rnn_output
        self.predicting_ids = tf.identity(predicting_decoder_output.predicted_ids[:, :, 0],name="logits")
        
        masks = tf.sequence_mask(self.Y_seq_len, tf.reduce_max(self.Y_seq_len), dtype=tf.float32)
        self.cost = tf.contrib.seq2seq.sequence_loss(logits = self.training_logits,
                                                     targets = self.Y,
                                                     weights = masks)
        
        self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
        y_t = tf.argmax(self.training_logits,axis=2)
        y_t = tf.cast(y_t, tf.int32)
        self.prediction = tf.boolean_mask(y_t, masks)
        mask_label = tf.boolean_mask(self.Y, masks)
        correct_pred = tf.equal(self.prediction, mask_label)
        correct_index = tf.cast(correct_pred, tf.float32)
        self.accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
size_layer = 128
num_layers = 2
embedded_size = 64
learning_rate = 1e-3
batch_size = 128
epoch = 10

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = Stemmer(size_layer, num_layers, embedded_size, len(dictionary_from), 
                len(dictionary_to), learning_rate)
sess.run(tf.global_variables_initializer())
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
def str_idx(corpus, dic, UNK=3):
    X = []
    for i in corpus:
        ints = []
        for k in i:
            ints.append(dic.get(k, UNK))
        X.append(ints)
    return X

# %%
X = str_idx(before, dictionary_from)
Y = str_idx(after, dictionary_to)

# %%
from sklearn.cross_validation import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size=0.2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def pad_sentence_batch(sentence_batch, pad_int):
    padded_seqs = []
    seq_lens = []
    max_sentence_len = max([len(sentence) for sentence in sentence_batch])
    for sentence in sentence_batch:
        padded_seqs.append(sentence + [pad_int] * (max_sentence_len - len(sentence)))
        seq_lens.append(len(sentence))
    return padded_seqs, seq_lens

# %%
from tqdm import tqdm
from sklearn.utils import shuffle
import time

for EPOCH in range(epoch):
    lasttime = time.time()
    total_loss, total_accuracy, total_loss_test, total_accuracy_test = 0, 0, 0, 0
    train_X, train_Y = shuffle(train_X, train_Y)
    test_X, test_Y = shuffle(test_X, test_Y)
    pbar = tqdm(range(0, len(train_X), batch_size), desc='train minibatch loop')
    for k in pbar:
        index = min(k+batch_size,len(train_X))
        batch_x, seq_x = pad_sentence_batch(train_X[k: k+batch_size], PAD)
        batch_y, seq_y = pad_sentence_batch(train_Y[k: k+batch_size], PAD)
        acc, loss, _ = sess.run([model.accuracy, model.cost, model.optimizer], 
                                      feed_dict={model.X:batch_x,
                                                model.Y:batch_y})
        total_loss += loss
        total_accuracy += acc
        pbar.set_postfix(cost=loss, accuracy = acc)
        
    pbar = tqdm(range(0, len(test_X), batch_size), desc='test minibatch loop')
    for k in pbar:
        index = min(k+batch_size,len(test_X))
        batch_x, seq_x = pad_sentence_batch(test_X[k: k+batch_size], PAD)
        batch_y, seq_y = pad_sentence_batch(test_Y[k: k+batch_size], PAD)
        acc, loss = sess.run([model.accuracy, model.cost], 
                                      feed_dict={model.X:batch_x,
                                                model.Y:batch_y})
        total_loss_test += loss
        total_accuracy_test += acc
        pbar.set_postfix(cost=loss, accuracy = acc)
        
    total_loss /= (len(train_X) / batch_size)
    total_accuracy /= (len(train_X) / batch_size)
    total_loss_test /= (len(test_X) / batch_size)
    total_accuracy_test /= (len(test_X) / batch_size)
        
    print('epoch: %d, avg loss: %f, avg accuracy: %f'%(EPOCH, total_loss, total_accuracy))
    print('epoch: %d, avg loss test: %f, avg accuracy test: %f'%(EPOCH, total_loss_test, total_accuracy_test))
# Out:
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 14.54it/s, accuracy=0.733, cost=0.965]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 30.25it/s, accuracy=0.691, cost=1.11]
# train minibatch loop:   1%|          | 2/260 [00:00<00:13, 19.24it/s, accuracy=0.738, cost=0.93]
# epoch: 0, avg loss: 1.327054, avg accuracy: 0.668514
# epoch: 0, avg loss test: 1.006337, avg accuracy test: 0.725494
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 14.10it/s, accuracy=0.771, cost=0.742]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.32it/s, accuracy=0.832, cost=0.529]
# train minibatch loop:   1%|          | 2/260 [00:00<00:20, 12.64it/s, accuracy=0.854, cost=0.483]
# epoch: 1, avg loss: 0.780559, avg accuracy: 0.776409
# epoch: 1, avg loss test: 0.581311, avg accuracy test: 0.823038
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 17.18it/s, accuracy=0.793, cost=0.641]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.32it/s, accuracy=0.834, cost=0.528]
# train minibatch loop:   1%|          | 2/260 [00:00<00:20, 12.40it/s, accuracy=0.865, cost=0.42]
# epoch: 2, avg loss: 0.535167, avg accuracy: 0.832748
# epoch: 2, avg loss test: 0.486392, avg accuracy test: 0.845531
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 15.16it/s, accuracy=0.869, cost=0.392]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.50it/s, accuracy=0.849, cost=0.431]
# train minibatch loop:   1%|          | 2/260 [00:00<00:15, 16.49it/s, accuracy=0.852, cost=0.491]
# epoch: 3, avg loss: 0.473295, avg accuracy: 0.849585
# epoch: 3, avg loss test: 0.436769, avg accuracy test: 0.860522
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 15.96it/s, accuracy=0.838, cost=0.49]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.59it/s, accuracy=0.895, cost=0.334]
# train minibatch loop:   1%|          | 2/260 [00:00<00:18, 13.77it/s, accuracy=0.849, cost=0.465]
# epoch: 4, avg loss: 0.418261, avg accuracy: 0.865479
# epoch: 4, avg loss test: 0.397559, avg accuracy test: 0.871747
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 16.35it/s, accuracy=0.856, cost=0.513]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.56it/s, accuracy=0.907, cost=0.273]
# train minibatch loop:   1%|          | 2/260 [00:00<00:16, 15.92it/s, accuracy=0.884, cost=0.357]
# epoch: 5, avg loss: 0.374489, avg accuracy: 0.879740
# epoch: 5, avg loss test: 0.359788, avg accuracy test: 0.884648
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 14.74it/s, accuracy=0.913, cost=0.298]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.63it/s, accuracy=0.909, cost=0.287]
# train minibatch loop:   0%|          | 0/260 [00:00<?, ?it/s]
# epoch: 6, avg loss: 0.329385, avg accuracy: 0.894845
# epoch: 6, avg loss test: 0.314494, avg accuracy test: 0.900551
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 14.76it/s, accuracy=0.91, cost=0.278]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.08it/s, accuracy=0.916, cost=0.257]
# train minibatch loop:   1%|          | 2/260 [00:00<00:16, 15.47it/s, accuracy=0.91, cost=0.29]
# epoch: 7, avg loss: 0.289100, avg accuracy: 0.908435
# epoch: 7, avg loss test: 0.273087, avg accuracy test: 0.914187
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 16.61it/s, accuracy=0.904, cost=0.298]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.46it/s, accuracy=0.931, cost=0.212]
# train minibatch loop:   1%|          | 2/260 [00:00<00:18, 13.66it/s, accuracy=0.926, cost=0.22]
# epoch: 8, avg loss: 0.255149, avg accuracy: 0.920163
# epoch: 8, avg loss test: 0.243077, avg accuracy test: 0.925212
# train minibatch loop: 100%|██████████| 260/260 [00:17<00:00, 15.26it/s, accuracy=0.923, cost=0.245]
# test minibatch loop: 100%|██████████| 65/65 [00:02<00:00, 31.55it/s, accuracy=0.928, cost=0.245]
# epoch: 9, avg loss: 0.224408, avg accuracy: 0.930682
# epoch: 9, avg loss test: 0.225840, avg accuracy test: 0.930108

# %%
predicted = sess.run(model.predicting_ids, 
                     feed_dict={model.X:batch_x})

# %%
for i in range(len(batch_x)):
    print('row %d'%(i+1))
    print('BEFORE:',''.join([rev_dictionary_from[n] for n in batch_x[i] if n not in [0,1,2,3]]))
    print('REAL AFTER:',''.join([rev_dictionary_to[n] for n in batch_y[i] if n not in[0,1,2,3]]))
    print('PREDICTED AFTER:',''.join([rev_dictionary_to[n] for n in predicted[i] if n not in[0,1,2,3]]),'\n')
# Out:
# row 1
# BEFORE: <mengedar>
# REAL AFTER: <edar>
# PREDICTED AFTER: <ddar>
#
# row 2
# BEFORE: <khairi>
# REAL AFTER: <khair>
# PREDICTED AFTER: <khairi>
#
# row 3
# BEFORE: <black-and-silver>
# REAL AFTER: <black-and-silver>
# PREDICTED AFTER: <blada>
#
# row 4
# BEFORE: <ungkapkan>
# REAL AFTER: <ungkap>
# PREDICTED AFTER: <ungkap>
#
# row 5
# BEFORE: <cabai>
# REAL AFTER: <cabai>
# PREDICTED AFTER: <cabai>
#
# row 6
# BEFORE: <relevannya>
# REAL AFTER: <relevan>
# PREDICTED AFTER: <relevan>
#
# row 7
# BEFORE: <activitate>
# REAL AFTER: <activitate>
# PREDICTED AFTER: <attivicate>
#
# row 8
# BEFORE: <berkedok>
# REAL AFTER: <kedok>
# PREDICTED AFTER: <kedok>
#
# row 9
# BEFORE: <coverage>
# REAL AFTER: <coverage>
# PREDICTED AFTER: <coverage>
#
# row 10
# BEFORE: <sebaga>
# REAL AFTER: <sebaga>
# PREDICTED AFTER: <sebaga>
#
# row 11
# BEFORE: <narrowly>
# REAL AFTER: <narrowly>
# PREDICTED AFTER: <narrowly>
#
# row 12
# BEFORE: <rsaf>
# REAL AFTER: <rsaf>
# PREDICTED AFTER: <rsaf>
#
# row 13
# BEFORE: <perajurit>
# REAL AFTER: <perajurit>
# PREDICTED AFTER: <perjjurit>
#
# row 14
# BEFORE: <kopassus>
# REAL AFTER: <kopassus>
# PREDICTED AFTER: <kopassus>
#
# row 15
# BEFORE: <redzuan>
# REAL AFTER: <redzuan>
# PREDICTED AFTER: <reduzan>
#
# row 16
# BEFORE: <luxembourg>
# REAL AFTER: <luxembourg>
# PREDICTED AFTER: <luxeboruug>
#
# row 17
# BEFORE: <disesatkan>
# REAL AFTER: <sesat>
# PREDICTED AFTER: <sesat>
#
# row 18
# BEFORE: <ber-hmi>
# REAL AFTER: <ber-hmi>
# PREDICTED AFTER: <ber-hmi>
#
# row 19
# BEFORE: <rentasan>
# REAL AFTER: <rentas>
# PREDICTED AFTER: <rentasan>
#
# row 20
# BEFORE: <perselingkuhan>
# REAL AFTER: <selingkuh>
# PREDICTED AFTER: <helung>
#
# row 21
# BEFORE: <chikungunya>
# REAL AFTER: <chikungunya>
# PREDICTED AFTER: <chuingkunya>
#
# row 22
# BEFORE: <pentabdiran>
# REAL AFTER: <pentabdiran>
# PREDICTED AFTER: <tarbir>
#
# row 23
# BEFORE: <serikat>
# REAL AFTER: <serikat>
# PREDICTED AFTER: <serikat>
#
# row 24
# BEFORE: <diplomasinya>
# REAL AFTER: <diplomasi>
# PREDICTED AFTER: <dilopasi>
#
# row 25
# BEFORE: <penanamnya>
# REAL AFTER: <tanam>
# PREDICTED AFTER: <naman>
#
# row 26
# BEFORE: <populis>
# REAL AFTER: <populis>
# PREDICTED AFTER: <populis>
#
# row 27
# BEFORE: <sediakala>
# REAL AFTER: <sediakala>
# PREDICTED AFTER: <sedialala>
#
# row 28
# BEFORE: <memberitahukan>
# REAL AFTER: <memberitahukan>
# PREDICTED AFTER: <butah>
#
# row 29
# BEFORE: <pengkhususan>
# REAL AFTER: <khusus>
# PREDICTED AFTER: <husus>
#
# row 30
# BEFORE: <waligereja>
# REAL AFTER: <waligereja>
# PREDICTED AFTER: <waligerera>
#
# row 31
# BEFORE: <hajat>
# REAL AFTER: <hajat>
# PREDICTED AFTER: <hajat>
#
# row 32
# BEFORE: <syariah>
# REAL AFTER: <syariah>
# PREDICTED AFTER: <syariah>
#
# row 33
# BEFORE: <proficient>
# REAL AFTER: <proficient>
# PREDICTED AFTER: <proficeint>
#
# row 34
# BEFORE: <disalirkan>
# REAL AFTER: <salir>
# PREDICTED AFTER: <salir>
#
# row 35
# BEFORE: <benta>
# REAL AFTER: <benta>
# PREDICTED AFTER: <benta>
#
# row 36
# BEFORE: <didiskusikan>
# REAL AFTER: <diskusi>
# PREDICTED AFTER: <diskusi>
#
# row 37
# BEFORE: <diselitkan>
# REAL AFTER: <selit>
# PREDICTED AFTER: <selit>
#
# row 38
# BEFORE: <pemuktamadan>
# REAL AFTER: <muktamad>
# PREDICTED AFTER: <mumakat>
#
# row 39
# BEFORE: <danger>
# REAL AFTER: <danger>
# PREDICTED AFTER: <danger>
#
# row 40
# BEFORE: <dakwanya>
# REAL AFTER: <dakwa>
# PREDICTED AFTER: <dakwa>
#
# row 41
# BEFORE: <loss>
# REAL AFTER: <loss>
# PREDICTED AFTER: <loss>
#
# row 42
# BEFORE: <bulan-bulan>
# REAL AFTER: <bulan>
# PREDICTED AFTER: <bulan>
#
# row 43
# BEFORE: <mexico-korea>
# REAL AFTER: <mexico-korea>
# PREDICTED AFTER: <mexico-rorea>
#
# row 44
# BEFORE: <need>
# REAL AFTER: <need>
# PREDICTED AFTER: <need>
#
# row 45
# BEFORE: <dpr>
# REAL AFTER: <dpr>
# PREDICTED AFTER: <dpr>
#
# row 46
# BEFORE: <regional>
# REAL AFTER: <regional>
# PREDICTED AFTER: <regional>
#
# row 47
# BEFORE: <wild>
# REAL AFTER: <wild>
# PREDICTED AFTER: <wild>
#
# row 48
# BEFORE: <pembelajarannya>
# REAL AFTER: <ajar>
# PREDICTED AFTER: <bajar>
#
# row 49
# BEFORE: <dun>
# REAL AFTER: <dun>
# PREDICTED AFTER: <dun>
#
# row 50
# BEFORE: <mengakar>
# REAL AFTER: <akar>
# PREDICTED AFTER: <akar>
#
# row 51
# BEFORE: <waheeda>
# REAL AFTER: <waheeda>
# PREDICTED AFTER: <waheeda>
#
# row 52
# BEFORE: <memfinalisasi>
# REAL AFTER: <final>
# PREDICTED AFTER: <memflisasi>
#
# row 53
# BEFORE: <bengong>
# REAL AFTER: <bengong>
# PREDICTED AFTER: <bengong>
#
# row 54
# BEFORE: <mountains>
# REAL AFTER: <mountains>
# PREDICTED AFTER: <mountains>
#
# row 55
# BEFORE: <zhafran>
# REAL AFTER: <zhafran>
# PREDICTED AFTER: <zhafran>
#
# row 56
# BEFORE: <dibiayai>
# REAL AFTER: <biaya>
# PREDICTED AFTER: <biaya>
#
# row 57
# BEFORE: <ngoi>
# REAL AFTER: <ngoi>
# PREDICTED AFTER: <ngoi>
#
# row 58
# BEFORE: <wuhan>
# REAL AFTER: <wuhan>
# PREDICTED AFTER: <wuhan>
#
# row 59
# BEFORE: <da-lam>
# REAL AFTER: <da-lam>
# PREDICTED AFTER: <da-lam>
#
# row 60
# BEFORE: <terbiasa>
# REAL AFTER: <biasa>
# PREDICTED AFTER: <birsa>
#
# row 61
# BEFORE: <berwarga>
# REAL AFTER: <warga>
# PREDICTED AFTER: <warga>
#
# row 62
# BEFORE: <papadakis>
# REAL AFTER: <papadakis>
# PREDICTED AFTER: <papakadis>
#
# row 63
# BEFORE: <ezatty>
# REAL AFTER: <ezatty>
# PREDICTED AFTER: <ezatty>
#
# row 64
# BEFORE: <wabak>
# REAL AFTER: <wabak>
# PREDICTED AFTER: <wabak>
#
# row 65
# BEFORE: <merimaskan>
# REAL AFTER: <rimas>
# PREDICTED AFTER: <rimas>
#
# row 66
# BEFORE: <terikat>
# REAL AFTER: <ikat>
# PREDICTED AFTER: <ikat>
#
# row 67
# BEFORE: <tiupan>
# REAL AFTER: <tiup>
# PREDICTED AFTER: <tiup>
#
# row 68
# BEFORE: <hills>
# REAL AFTER: <hills>
# PREDICTED AFTER: <hills>
#
# row 69
# BEFORE: <hasina>
# REAL AFTER: <hasina>
# PREDICTED AFTER: <hasina>
#
# row 70
# BEFORE: <drama>
# REAL AFTER: <drama>
# PREDICTED AFTER: <drama>
#
# row 71
# BEFORE: <coal>
# REAL AFTER: <coal>
# PREDICTED AFTER: <coal>
#
# row 72
# BEFORE: <bobsleds>
# REAL AFTER: <bobsleds>
# PREDICTED AFTER: <bosbleds>
#
# row 73
# BEFORE: <simposim>
# REAL AFTER: <simposim>
# PREDICTED AFTER: <simposim>
#
# row 74
# BEFORE: <diungkit>
# REAL AFTER: <ungkit>
# PREDICTED AFTER: <ungkut>
#
# row 75
# BEFORE: <ilias>
# REAL AFTER: <ilias>
# PREDICTED AFTER: <ilias>
#
# row 76
# BEFORE: <rekaan>
# REAL AFTER: <reka>
# PREDICTED AFTER: <reka>
#
# row 77
# BEFORE: <students>
# REAL AFTER: <students>
# PREDICTED AFTER: <stutends>
#
# row 78
# BEFORE: <dipersoalkan>
# REAL AFTER: <soal>
# PREDICTED AFTER: <soal>
#
# row 79
# BEFORE: <menculik>
# REAL AFTER: <culik>
# PREDICTED AFTER: <culik>
#
# row 80
# BEFORE: <yeo>
# REAL AFTER: <yeo>
# PREDICTED AFTER: <yeo>
#
# row 81
# BEFORE: <pembohongan>
# REAL AFTER: <bohong>
# PREDICTED AFTER: <bohong>
#
# row 82
# BEFORE: <desert>
# REAL AFTER: <desert>
# PREDICTED AFTER: <desert>
#
# row 83
# BEFORE: <mengulagi>
# REAL AFTER: <mengulagi>
# PREDICTED AFTER: <ulang>
#
# row 84
# BEFORE: <mengutusnya>
# REAL AFTER: <utus>
# PREDICTED AFTER: <usus>
#
# row 85
# BEFORE: <pemikirannya>
# REAL AFTER: <pikir>
# PREDICTED AFTER: <pirik>
#
# row 86
# BEFORE: <rebutlah>
# REAL AFTER: <rebut>
# PREDICTED AFTER: <rebut>
#
# row 87
# BEFORE: <burhanieditor>
# REAL AFTER: <burhanieditor>
# PREDICTED AFTER: <burhaniontior>
#
# row 88
# BEFORE: <kohort>
# REAL AFTER: <kohort>
# PREDICTED AFTER: <kohort>
#
# row 89
# BEFORE: <padil>
# REAL AFTER: <padil>
# PREDICTED AFTER: <padil>
#
# row 90
# BEFORE: <perinci>
# REAL AFTER: <perinci>
# PREDICTED AFTER: <perinci>
#
# row 91
# BEFORE: <direka-reka>
# REAL AFTER: <reka>
# PREDICTED AFTER: <rerka>
#
# row 92
# BEFORE: <cubesats>
# REAL AFTER: <cubesats>
# PREDICTED AFTER: <cubesats>
#
# row 93
# BEFORE: <tanjak>
# REAL AFTER: <tanjak>
# PREDICTED AFTER: <tanjak>
#
# row 94
# BEFORE: <roquiya>
# REAL AFTER: <roquiya>
# PREDICTED AFTER: <roquiya>
#
# row 95
# BEFORE: <lfa>
# REAL AFTER: <lfa>
# PREDICTED AFTER: <lfa>
#
# row 96
# BEFORE: <utamakan>
# REAL AFTER: <utama>
# PREDICTED AFTER: <utama>
#
# row 97
# BEFORE: <katalisator>
# REAL AFTER: <katalisator>
# PREDICTED AFTER: <katalisator>
#
# row 98
# BEFORE: <popularitinya>
# REAL AFTER: <popularitinya>
# PREDICTED AFTER: <populatirinya>
#
# row 99
# BEFORE: <lead>
# REAL AFTER: <lead>
# PREDICTED AFTER: <lead>
#
# row 100
# BEFORE: <lanjutnya>
# REAL AFTER: <lanjut>
# PREDICTED AFTER: <lanjut>
#
# row 101
# BEFORE: <fare>
# REAL AFTER: <fare>
# PREDICTED AFTER: <fare>
#
# row 102
# BEFORE: <condemns>
# REAL AFTER: <condemns>
# PREDICTED AFTER: <condemns>
#
# row 103
# BEFORE: <diblokir>
# REAL AFTER: <blokir>
# PREDICTED AFTER: <diklobir>
#
# row 104
# BEFORE: <fadhilah>
# REAL AFTER: <fadhilah>
# PREDICTED AFTER: <fadhilah>
#
# row 105
# BEFORE: <theguardian>
# REAL AFTER: <theguardian>
# PREDICTED AFTER: <theugarigan>
#
# row 106
# BEFORE: <bloombergbisnis>
# REAL AFTER: <bloombergbisnis>
# PREDICTED AFTER: <blooerbibbligis>
#
# row 107
# BEFORE: <venice>
# REAL AFTER: <venice>
# PREDICTED AFTER: <venice>
#
# row 108
# BEFORE: <linden>
# REAL AFTER: <linden>
# PREDICTED AFTER: <linden>
#
# row 109
# BEFORE: <kehutanan>
# REAL AFTER: <hutan>
# PREDICTED AFTER: <huta
#
# row 110
# BEFORE: <menyikapi>
# REAL AFTER: <sikap>
# PREDICTED AFTER: <sikap>
#
# row 111
# BEFORE: <menang>
# REAL AFTER: <menang>
# PREDICTED AFTER: <tenang>
#
# row 112
# BEFORE: <pembaikan>
# REAL AFTER: <baik>
# PREDICTED AFTER: <bak>
#
# row 113
# BEFORE: <al-kaafi>
# REAL AFTER: <al-kaafi>
# PREDICTED AFTER: <al-kaffi>
#
# row 114
# BEFORE: <penanti>
# REAL AFTER: <nanti>
# PREDICTED AFTER: <tant
